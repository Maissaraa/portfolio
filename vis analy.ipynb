# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path="D:\Ai academy\python\sesstion 5\ecommerce_sales.csv"
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\A'
# <>:1: SyntaxWarning: invalid escape sequence '\A'
# C:\Users\Friends\AppData\Local\Temp\ipykernel_5868\112482252.py:1: SyntaxWarning: invalid escape sequence '\A'
#   path="D:\Ai academy\python\sesstion 5\ecommerce_sales.csv"

# %%
data=pd.read_csv(path)
df=data.copy()

# %%
df.head()
# Out:
#    Company_ID Purchase_Date Product_Category  Quantity  Total_Sales  Gender  \
# 0           4    2021-12-19             Home         8   423.470537  Female
# 1           3    2021-10-10           Beauty         2   394.399325  Female
# 2           6    2021-06-28             Home         9   157.567488    Male
# 3           2    2021-10-14            Books         1   113.351819    Male
# 4           6    2020-02-09           Beauty         4    85.729982    Male
#
#   Marital_Status  Price_Per_Unit       Customer_Type  Age
# 0       Divorced       19.412629        New Customer   54
# 1       Divorced       34.296387        New Customer   71
# 2        Widowed       15.469916        New Customer   80
# 3        Married        8.158978  Returning Customer   26
# 4         Single       26.598399        New Customer   46

# %%
plt.hist(df['Age'],bins=15)

plt.xlabel('Age')
plt.ylabel('frequency')
plt.title('Age amount distrbution')

plt.show()

# %%
path1="D:\Ai academy\python\sesstion 7\E-commerce-Super_market.xlsx"
data1=data=pd.read_excel(path1)
df1=data1.copy()
df
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\A'
# <>:1: SyntaxWarning: invalid escape sequence '\A'
# C:\Users\Friends\AppData\Local\Temp\ipykernel_5868\2932344367.py:1: SyntaxWarning: invalid escape sequence '\A'
#   path1="D:\Ai academy\python\sesstion 7\E-commerce-Super_market.xlsx"
#       Company_ID Purchase_Date Product_Category  Quantity  Total_Sales  \
# 0              4    2021-12-19             Home         8   423.470537
# 1              3    2021-10-10           Beauty         2   394.399325
# 2              6    2021-06-28             Home         9   157.567488
# 3              2    2021-10-14            Books         1   113.351819
# 4              6    2020-02-09           Beauty         4    85.729982
# ...          ...           ...              ...       ...          ...
# 9995           2    2020-08-05             Home         5   439.088306
# 9996           4    2020-12-15      Electronics        10   316.121274
# ...

# %%
df1['Sales'].describe()
# Out:
# count     9994.000000
# mean       229.858001
# std        623.245101
# min          0.444000
# 25%         17.280000
# 50%         54.490000
# 75%        209.940000
# max      22638.480000
# Name: Sales, dtype: float64

# %%
edit=df1[df1['Sales']<= 209.940000]
edit.head()
# Out:
#    Row ID Order Date  Ship Date       Ship Mode Customer ID    Customer Name  \
# 2       3 2016-06-12 2016-06-16    Second Class    DV-13045  Darrin Van Huff
# 4       5 2015-10-11 2015-10-18  Standard Class    SO-20335   Sean O'Donnell
# 5       6 2014-06-09 2014-06-14  Standard Class    BH-11710  Brosina Hoffman
# 6       7 2014-06-09 2014-06-14  Standard Class    BH-11710  Brosina Hoffman
# 8       9 2014-06-09 2014-06-14  Standard Class    BH-11710  Brosina Hoffman
#
#      Segment        Country             City       State  Postal Code Region  \
# 2  Corporate  United States      Los Angeles  California        90036   West
# 4   Consumer  United States  Fort Lauderdale     Florida        33311  South
# 5   Consumer  United States      Los Angeles  California        90032   West
# 6   Consumer  United States      Los Angeles  California        90032   West
# 8   Consumer  United States      Los Angeles  California        90032   West
#
# ...

# %%
plt.hist(edit['Sales'],bins=15)

plt.xlabel('Sales')
plt.ylabel('frequency')
plt.title('Age amount distrbution')

plt.show()

# %%
#plt.figure(figsize=5,3)

sns.boxenplot(y='Sales',data = df1)
plt.title('sales amount')
# Out:
# Text(0.5, 1.0, 'sales amount')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order Date     9994 non-null   datetime64[ns]
#  2   Ship Date      9994 non-null   datetime64[ns]
#  3   Ship Mode      9994 non-null   object
#  4   Customer ID    9994 non-null   object
#  5   Customer Name  9994 non-null   object
#  6   Segment        9994 non-null   object
#  7   Country        9994 non-null   object
#  8   City           9994 non-null   object
#  9   State          9994 non-null   object
#  10  Postal Code    9994 non-null   int64
#  11  Region         9994 non-null   object
#  12  Product ID     9994 non-null   object
#  13  Category       9994 non-null   object
#  14  Sub-Category   9994 non-null   object
#  15  Product Name   9994 non-null   object
#  16  Sales          9994 non-null   float64
# ...

# %%
df1['Month']=df1['Order Date'].dt.month

# %%
sns.countplot(x='Month',data=df1)
# Out:
# <Axes: xlabel='Month', ylabel='count'>

# %%
df1['day']=df1['Order Date'].dt.day_name()

# %%
sns.countplot(x='day',data=df1)

plt.xticks(rotation=45)
# Out:
# ([0, 1, 2, 3, 4, 5, 6],
#  [Text(0, 0, 'Tuesday'),
#   Text(1, 0, 'Sunday'),
#   Text(2, 0, 'Monday'),
#   Text(3, 0, 'Saturday'),
#   Text(4, 0, 'Wednesday'),
#   Text(5, 0, 'Friday'),
#   Text(6, 0, 'Thursday')])

# %%
resamp=df1.resample('Y',on='Ship Date')['Quantity'].count()
plt.show()
# Out:
# C:\Users\Friends\AppData\Local\Temp\ipykernel_5868\2220577680.py:1: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   resamp=df1.resample('Y',on='Ship Date')['Quantity'].count()

# %%
resamp
# Out:
# Ship Date
# 2014-12-31    1940
# 2015-12-31    2131
# 2016-12-31    2578
# 2017-12-31    3303
# 2018-12-31      42
# Freq: YE-DEC, Name: Quantity, dtype: int64

# %%
plt.plot(resamp,marker='o')

# %%
pivot = df1.pivot_table(index='Category', 
                             values='Sales', 
                             columns='Segment', 
                             aggfunc='sum',
                             fill_value=0)
pivot
# Out:
# Segment            Consumer    Corporate  Home Office
# Category
# Furniture        391049.312  229019.7858  121930.6975
# Office Supplies  363952.136  230676.4620  124418.4340
# Technology       406399.897  246450.1190  183304.0170

# %%
pivot.plot(kind='bar')
# Out:
# <Axes: xlabel='Category'>

# %%
corretion_matrix=df1.corr(numeric_only=True)
sns.heatmap(corretion_matrix,
           annot=True)
# Out:
# <Axes: >

# %%
# !pip install wordcloud

# %%
from wordcloud import WordCloud

# %%
wordcloud = df1(width=800, height=400, background_color='white').\
            generate(' '.join(df1['Product Name']))
plt.figure(figsize=(10,6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud - Most Frequent Product Categories')
plt.show()

# %%
path=r"D:\Ai academy\python\sesstion 5\ecommerce_sales.csv"
data=pd.read_csv(path)
ecom=data.copy()

# %%
labels=['>20','20-30','30-45','45-60','>60']
bins=[0, 20, 30, 45, 60, 100]
ecom['AgeGroub']=pd.cut(ecom['Age'],
                        bins=bins,
                        labels=labels)

# %%
ecom['AgeGroub'].value_counts

# %%
import plotly.express as px

# %%
ecom.head()

# %%
path=r"D:\Ai academy\python\sesstion 9\melb_data.csv"
data=pd.read_csv(path)
melb=data.copy()

# %%
melb.head()

# %%
import plotly.express as px

# %%
fig=px.scatter(melb,x='Price',y='Distance',
               color='Type',
               width=600,height=600)

# %%
df2=px.data.stocks()
fig1=p.line
